# %% [markdown]
# # Task 55: Tutorial - Time Series Analysis with Pandas
#
# This notebook introduces time series analysis using Pandas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1: Create a Date Range

# %%
dates = pd.date_range(start='2025-01-01', periods=30, freq='D')
dates[:5]

# %% [markdown]
# ## Step 2: Create a Time Series Dataset

# %%
data = pd.DataFrame({
    'Date': dates,
    'Sales': np.random.randint(100, 500, size=30)
})
data.set_index('Date', inplace=True)
data.head()

# %% [markdown]
# ## Step 3: Plot the Time Series

# %%
plt.figure(figsize=(10,5))
plt.plot(data.index, data['Sales'])
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Daily Sales Time Series')
plt.show()

# %% [markdown]
# ## Step 4: Calculate Moving Average

# %%
data['Moving_Average'] = data['Sales'].rolling(window=7).mean()
data.head(10)

# %% [markdown]
# ## Step 5: Resample Data by Week

# %%
weekly_sales = data.resample('W').sum()
weekly_sales
