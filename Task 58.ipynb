# %% [markdown]
# # Feedforward Neural Networks: A Quick Primer for Deep Learning
#
# This notebook provides a concise introduction to Feedforward Neural Networks (FNNs), one of the fundamental architectures in Deep Learning.

# %% [markdown]
# ## 1. Introduction
# - What is a Feedforward Neural Network?
# - Input Layer
# - Hidden Layers
# - Output Layer

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Activation Functions

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def relu(x):
    return np.maximum(0, x)

def tanh(x):
    return np.tanh(x)

# %% [markdown]
# ## 3. Forward Propagation Example

# %%
inputs = np.array([1.0, 2.0, 3.0])
weights = np.array([0.2, 0.8, -0.5])
bias = 1.0

output = sigmoid(np.dot(inputs, weights) + bias)
print('Neuron Output:', output)

# %% [markdown]
# ## 4. A Small Feedforward Network

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

print('Inputs:')
print(X)
print('Targets:')
print(y)

# %% [markdown]
# ## 5. Feedforward Neural Network with Scikit-Learn

# %%
from sklearn.neural_network import MLPClassifier

model = MLPClassifier(hidden_layer_sizes=(5,), max_iter=1000, random_state=42)
model.fit(X, y.ravel())

predictions = model.predict(X)
print('Predictions:', predictions)

# %% [markdown]
# ## 6. Key Concepts
# - Forward Propagation
# - Weights and Biases
# - Activation Functions
# - Hidden Layers
# - Training and Prediction
